# %% [markdown]
# <a href="https://colab.research.google.com/github/angelinawong1210/VietnameseFakeNews/blob/main/FakeNews_NaiveBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %%
truenews = pd.read_csv('/content/Fake.csv')
fakenews = pd.read_csv('/content/Real.csv')

# %%
fakenews.head()
# Out:
#                                               tittle  \
# 0  Tung tin Mr Bean qua đời để phát tán virus độc...
# 1  Nhân chứng kể lại phút đối mặt với tên cướp ng...
# 2  Hãng chuyển phát nhanh phá sản, khách từ Sài G...
# 3  Go-Jek và Grab giành giật thị trường Indonesia...
# 4  Không có chuyện thí điểm chữ viết 'Tiếq Việt' ...
#
#                                                 text                domain  \
# 0   Hôm 19/7, nhiều độc giả cảnh báo nhau trên mạ...  https://news.zing.vn
# 1  \n "Lúc đó nhân viên nữ nên la hét, còn tôi và...          news.zing.vn
# 2   Nghe tin GNN Express tuyên bố phá sản, nhiều ...          news.zing.vn
# 3   Indonesia là chiến trường chính của hai start...          news.zing.vn
# 4   Ông Phạm Ngọc Thanh, Phó giám đốc Sở GD&ĐT TP...          news.zing.vn
#
#       topic
# 0  Giải trí
# 1  Đời sống
# 2  Kinh tế
# 3  Kinh tế
# 4  Giáo dục

# %%
truenews.head()
# Out:
#                                               tittle  \
# 0  Thủ tướng Abe cúi đầu xin lỗi vì hành động phi...
# 1  Thủ tướng Nhật cúi đầu xin lỗi vì tinh thần ph...
# 2  Choáng! Cơ trưởng đeo khăn quàng quẩy banh nóc...
# 3       Chưa bao giờ nhạc Kpop lại dễ hát đến thế!!!
# 4  Đại học Hutech sẽ áp dụng cải cách "Tiếq Việt"...
#
#                                                 text               domain  \
# 0   Theo Sankei Sports, sáng nay Thủ tướng Nhật B...         binhluan.biz
# 1  Sáng 19/6, Thủ tướng Nhật Bản Shinzo Abe công ...         www.ipick.vn
# 2  Choáng! Cơ trưởng đeo khăn quàng quẩy banh nóc...       tintucqpvn.net
# 3  Chưa bao giờ nhạc Kpop lại dễ hát đến thế!!!\n...       tintucqpvn.net
# 4   Mới đây, ông Phạm Ngọc Thanh, Phó giám đốc Sở...  www.gioitreviet.net
#
#        topic
# 0  Thể thao
# 1   Thể thao
# 2  Đời sống
# 3  Giải trí
# 4  Giáo dục

# %%
fakenews.describe()
# Out:
#                                                 tittle  \
# count                                              150
# unique                                             149
# top     Nhiều máy bay không thể đáp xuống Tân Sơn Nhất
# freq                                                 2
#
#                                                      text         domain  \
# count                                                 150            150
# unique                                                150             12
# top      Hôm 19/7, nhiều độc giả cảnh báo nhau trên mạ...  vnexpress.net
# freq                                                    1            100
#
#             topic
# count         150
# unique         15
# top     Đời sống
# freq           48

# %%
truenews.describe()
# Out:
#                                                    tittle  \
# count                                                 149
# unique                                                148
# top     Những dấu hiệu nhận biết nhà bạn đang có ma và...
# freq                                                    2
#
#                                                      text      domain  \
# count                                                 149         111
# unique                                                149          27
# top      Theo Sankei Sports, sáng nay Thủ tướng Nhật B...  tinvn.info
# freq                                                    1          68
#
#             topic
# count         149
# unique         12
# top     Đời sống
# freq          100

# %%
truenews['True/Fake']='True'
fakenews['True/Fake']='Fake'

# %%
# Combine the 2 DataFrames into a single data frame
news = pd.concat([truenews, fakenews])
news["Article"] = news["tittle"] + news["text"]
news.sample(frac = 1) #Shuffle 100%
# Out:
#                                                 tittle  \
# 22   Bị cảnh báo giả, khách trên máy bay TP.HCM đi ...
# 122  X͏͏ót͏͏ x͏͏a͏͏ m͏͏ẹ “n͏͏úp͏͏” t͏͏r͏͏o͏͏n͏͏g͏͏ ...
# 10   KHẨN CẤP: Hàng loạt trẻ em nhập viện vì ngộ độ...
# 0    Thủ tướng Abe cúi đầu xin lỗi vì hành động phi...
# 38   Khải Hoàn Môn tan hoang sau cuộc bạo loạn lớn ...
# ..                                                 ...
# 41   Ôtô 'chôn chân' vì bị chặn đầu bởi trăm xe máy...
# 147  Cô gái bị thanh niên đi SH giật dây chuyền, tà...
# 47   Ba du khách tử vong ở Đà Nẵng trúng chất độc ả...
# 72    Nam cảnh sát Mỹ truy đuổi nữ sinh viên để sàm sỡ
# 75   Cô gái 17 tuổi được NASA đào tạo để đặt chân l...
#
#                                                   text         domain  \
# 22   \n TTO - Chuyến bay VJ198 của Hãng Vietjet Air...     tuoitre.vn
# 122  N͏ց͏ư͏ờі͏ m͏ẹ b͏і͏ết͏ ϲ͏ᴏ͏ո͏ b͏ị ϲ͏ư͏ỡո͏ց͏ b͏ứ...            NaN
# 10    Xét nghiệm ban đầu từ các trẻ nhập viện cho t...  phapluat.news
# 0     Theo Sankei Sports, sáng nay Thủ tướng Nhật B...   binhluan.biz
# 38    Bạo loạn bùng phát ở thủ đô Paris của Pháp hô...  vnexpress.net
# ..                                                 ...            ...
# 41    Tài xế ôtô bất lực vì bị chặn đầu bởi trăm xe...  vnexpress.net
# 147  B͏an đầu tưởng đôi tình nhân đang cãi nhau, nh...            NaN
# 47    Giám định thuốc diệt côn trùng tại khách sạn ...  vnexpress.net
# 72    Thói quen lạ của chú chó tố cáo ông chủ vứt x...  vnexpress.net
# 75    Alyssa Carson (17 tuổi) đến từ bang Louisiana...  vnexpress.net
#
#            topic True/Fake                                            Article
# 22     Đời sống       Fake  Bị cảnh báo giả, khách trên máy bay TP.HCM đi ...
# 122     An ninh       True  X͏͏ót͏͏ x͏͏a͏͏ m͏͏ẹ “n͏͏úp͏͏” t͏͏r͏͏o͏͏n͏͏g͏͏ ...
# 10         Y tế       True  KHẨN CẤP: Hàng loạt trẻ em nhập viện vì ngộ độ...
# 0      Thể thao       True  Thủ tướng Abe cúi đầu xin lỗi vì hành động phi...
# 38     Đời sống       Fake  Khải Hoàn Môn tan hoang sau cuộc bạo loạn lớn ...
# ..           ...       ...                                                ...
# 41   Giao thông       Fake  Ôtô 'chôn chân' vì bị chặn đầu bởi trăm xe máy...
# 147     An ninh       True  Cô gái bị thanh niên đi SH giật dây chuyền, tà...
# 47         Y tế       Fake  Ba du khách tử vong ở Đà Nẵng trúng chất độc ả...
# 72      An ninh       Fake  Nam cảnh sát Mỹ truy đuổi nữ sinh viên để sàm ...
# 75     Đời sống       Fake  Cô gái 17 tuổi được NASA đào tạo để đặt chân l...
#
# [299 rows x 6 columns]

# %%
import nltk 
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
#Data Cleaning
from nltk.corpus import stopwords
import string

# %%
def process_text(s):

    # Check string to see if they are a punctuation
    nopunc = [char for char in s if char not in string.punctuation]

    # Join the characters again to form the string.
    nopunc = ''.join(nopunc)
    
    # Convert string to lowercase and remove stopwords
    clean_string = [word for word in nopunc.split()]
    return clean_string

# %%
# Tokenize the Article
#rerun, takes LOOOONG
news['Clean Text'] = news['Article'].apply(process_text)

# %%
news.sample(5)
# Out:
#                                                 tittle  \
# 81   Đường đi bộ lát gỗ lim ven sông Hương sắp hoàn...
# 117  Đối tượng cuối cùng trong vụ trốn khỏi trại tạ...
# 42   Phụ huynh tố cáo trường cho trẻ ăn rau thối, t...
# 21   VIDEO: Xót xa nhìn cảnh cụ bà 87 tuổi co ro tr...
# 96   Chỉ vài giây dừng chờ đèn đỏ, người đàn ông nà...
#
#                                                   text              domain  \
# 81    Nhiều chuyên gia ở Huế lo ngại việc lát gỗ li...       vnexpress.net
# 117  Khoảng 4h sáng nay 8-12, biết mình không trốn ...       dantri.com.vn
# 42    7h50 ngày 3/12, chị Nguyễn Thị Nga đưa con 3 ...       vnexpress.net
# 21   Không chồng con, mấy chục năm qua bà Nguyễn Th...  haiduong.tintuc.vn
# 96   \n Nhiều người không dám ra khỏi nhà cũng chỉ ...          tinvn.info
#
#          topic True/Fake                                            Article  \
# 81   Đời sống       Fake  Đường đi bộ lát gỗ lim ven sông Hương sắp hoàn...
# 117   An ninh       Fake  Đối tượng cuối cùng trong vụ trốn khỏi trại tạ...
# 42    Giáo dục      Fake  Phụ huynh tố cáo trường cho trẻ ăn rau thối, t...
# 21   Đời sống       True  VIDEO: Xót xa nhìn cảnh cụ bà 87 tuổi co ro tr...
# 96   Đời sống       True  Chỉ vài giây dừng chờ đèn đỏ, người đàn ông nà...
#
#                                             Clean Text
# 81   [Đường, đi, bộ, lát, gỗ, lim, ven, sông, Hương...
# 117  [Đối, tượng, cuối, cùng, trong, vụ, trốn, khỏi...
# 42   [Phụ, huynh, tố, cáo, trường, cho, trẻ, ăn, ra...
# 21   [VIDEO, Xót, xa, nhìn, cảnh, cụ, bà, 87, tuổi,...
# 96   [Chỉ, vài, giây, dừng, chờ, đèn, đỏ, người, đà...

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
bow_transformer = CountVectorizer(analyzer=process_text).fit(news['Clean Text'])

print(len(bow_transformer.vocabulary_)) #Total vocab words
# Out:
# 298

# %%
#Bag-of-Words (bow) transform the entire DataFrame of text
news_bow = bow_transformer.transform(news['Clean Text'])

# %%
print('Shape of Sparse Matrix: ', news_bow.shape)
print('Amount of Non-Zero occurences: ', news_bow.nnz)
# Out:
# Shape of Sparse Matrix:  (299, 298)
# Amount of Non-Zero occurences:  299

# %%
sparsity = (100.0 * news_bow.nnz / (news_bow.shape[0] * news_bow.shape[1]))
print('sparsity: {}'.format(round(sparsity)))
# Out:
# sparsity: 0

# %%
from sklearn.feature_extraction.text import TfidfTransformer

tfidf_transformer = TfidfTransformer().fit(news_bow)
news_tfidf = tfidf_transformer.transform(news_bow)
print(news_tfidf.shape)
# Out:
# (299, 298)

# %%
#Train Naive Bayes Model
from sklearn.naive_bayes import MultinomialNB
fakenews_detect_model = MultinomialNB().fit(news_tfidf, news['True/Fake'])

# %%
#Model Evaluation
predictions = fakenews_detect_model.predict(news_tfidf)
print(predictions)
# Out:
# ['True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True'
#  'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'True' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake'
#  'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake' 'Fake']

# %%
from sklearn.metrics import classification_report
print (classification_report(news['True/Fake'], predictions))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       1.00      1.00      1.00       150
#         True       1.00      1.00      1.00       149
#
#     accuracy                           1.00       299
#    macro avg       1.00      1.00      1.00       299
# weighted avg       1.00      1.00      1.00       299

# %%
from sklearn.model_selection import train_test_split

news_train, news_test, text_train, text_test = train_test_split(news['Article'], news['True/Fake'], test_size=0.3)

print(len(news_train), len(news_test), len(news_train) + len(news_test))
# Out:
# 209 90 299

# %%
from sklearn.pipeline import Pipeline

pipeline = Pipeline([
    ('bow', CountVectorizer(analyzer=process_text)),  
    ('tfidf', TfidfTransformer()),  
    ('classifier', MultinomialNB()),  
])
pipeline.fit(news_train,text_train)
# Out:
# Pipeline(steps=[('bow',
#                  CountVectorizer(analyzer=<function process_text at 0x7fd20dcb6670>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
prediction = pipeline.predict(news_test)

# %%
print(classification_report(prediction,text_test))
# Out:
#               precision    recall  f1-score   support
#
#         Fake       0.88      0.98      0.92        43
#         True       0.98      0.87      0.92        47
#
#     accuracy                           0.92        90
#    macro avg       0.93      0.92      0.92        90
# weighted avg       0.93      0.92      0.92        90
